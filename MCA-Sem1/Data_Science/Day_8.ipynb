# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mpl
import seaborn as sb

# %% [markdown]
# # Import the CSV File

# %%
df=pd.read_csv('USA_Housing.csv')
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %% [markdown]
# # Plot: Avg. Area Income vs. Price

# %%
df_Price_Income=pd.DataFrame({'Price':round(df['Price'],3),'Income':round(df['Avg. Area Income'],3)})
df_Price_Income=df_Price_Income.sort_values(by='Income')
mpl.plot(df_Price_Income['Income'],round(df_Price_Income['Price'],3),'r')
mpl.xlabel('Income')
mpl.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
df_Price_Income
# Out:
#             Price      Income
# 39     302355.836   17796.631
# 3069  1077805.578   35454.715
# 2092   449331.584   35608.986
# 4855   299863.040   35797.323
# 1459   143027.364   35963.331
# ...           ...         ...
# 2719  2370231.320  101599.671
# 962   1938866.490  101928.858
# 3541  1754937.715  102881.121
# 1734  1742431.663  104702.724
# 693   2332110.740  107701.748
#
# [5000 rows x 2 columns]
